# %%
import import_ipynb
import pandas, os, geopy 
from pandas import DataFrame

from geopy.distance import geodesic, lonlat, distance

#PROBLEM 1 --------------------------------------------------------------------------------------------------------

print("--------------------------------- PROBLEM 1 ---------------------------------")

df1 = pandas.read_csv("locationsofstops.csv")
df2 = pandas.read_csv("distancebetweenstops.csv")

from geopy.geocoders import Nominatim
nom = geopy.geocoders.Nominatim(user_agent="my app")
df1["Address"] = df1["location"].apply(nom.geocode, timeout = 10)

#Task 1 : Marking and getting stops 

df1["Latitude"] = df1["Address"].apply(lambda x: x.latitude if x != None else None)
df1["Longitude"] = df1["Address"].apply(lambda x: x.longitude if x != None else None)
df1["Coordinate"] = df1["Latitude"].astype(str)+","+df1["Longitude"].astype(str)

#Task 2 : Adding distance between stops
#STOP 1
#KL Sentral -KLIA
origin = (df1.at[0,"Coordinate"])
stop = (df1.at[1,"Coordinate"])
distance1 = int(geodesic(origin,stop).km)

#KL Sentral - Terminal Skypark Komuter Station
origin1 = (df1.at[0,"Coordinate"])
stop1 = (df1.at[9,"Coordinate"])
distance12 = int(geodesic(origin1, stop1).km)

df2['Stop 1'].replace({"Kuala Lumpur International Airport":"Kuala Lumpur International Airport"+", "
                       +str(distance1)+" km"}, inplace = True)
df2['Stop 1'].replace({"Terminal Skypark Komuter Station":"Terminal Skypark Komuter Station"+", "
                       +str(distance12)+" km"}, inplace = True)

#STOP 2
#KLIA - Terminal TUTA
origin2 = (df1.at[1,"Coordinate"])
stop2 = (df1.at[2,"Coordinate"])
distance2 = int(geodesic(origin2, stop2).km)

#Terminal Skypark Komuter - Sultan Abdul Aziz Shah Airport
origin3 = (df1.at[9,"Coordinate"])
stop3 = (df1.at[10,"Coordinate"])
distance13 = int(geodesic(origin3, stop3).km)

#KLIA - Changi International Airport
origin4 = (df1.at[1,"Coordinate"])
stop4 = (df1.at[4,"Coordinate"])
distance4 = int(geodesic(origin4, stop4).km)

#KLIA - Senai Airport
origin5 = (df1.at[1,"Coordinate"])
stop5 = (df1.at[7,"Coordinate"])
distance8 = int(geodesic(origin5, stop5).km)

#Adding distance
df2['Stop 2'].replace({"Terminal TUTA":"Terminal TUTA"+", "+str(distance2)+" km"}, inplace = True)
df2['Stop 2'].replace({"Sultan Abdul Aziz Shah Airport":"Sultan Abdul Aziz Shah Airport"+", "
                       +str(distance13)+" km"}, inplace = True)
df2['Stop 2'].replace({"Changi Airport":"Changi Airport"+", "+str(distance4)+" km"}, inplace = True)
df2['Stop 2'].replace({"Senai Airport":"Senai Airport"+", "+str(distance8)+" km"}, inplace = True)

#Stop 3
#Terminal TUTA - Legoland
origin6 = (df1.at[2,"Coordinate"])
stop6 = (df1.at[3,"Coordinate"])
distance3 = int(geodesic(origin6, stop6).km)

#Sultan Abdul Aziz Shah Airport - Senai Airport
origin7 = (df1.at[10,"Coordinate"])
stop7 = (df1.at[7,"Coordinate"])
distance11 = int(geodesic(origin7, stop7).km)

#Sultan Abdul Aziz Shah Airport - Singapore Seletar Airport
origin8 = (df1.at[10,"Coordinate"])
stop8 = (df1.at[11,"Coordinate"])
distance14 = int(geodesic(origin8, stop8).km)

#Changi Airport - Tanah Merah MRT Station
origin9 = (df1.at[4,"Coordinate"])
stop9 = (df1.at[5,"Coordinate"])
distance5 = int(geodesic(origin9, stop9).km)

#Senai Airport - Johor Bahru Sentral
origin10 = (df1.at[7,"Coordinate"])
stop10 = (df1.at[8,"Coordinate"])
distance9 = int(geodesic(origin10, stop10).km)

#Adding Distance
df2['Stop 3'].replace({"Legoland":"Legoland"+", "+str(distance3)+" km"}, inplace = True)
df2['Stop 3'].replace({"Senai Airport":"Senai Airport"+", "+str(distance11)+" km"}, inplace = True)
df2['Stop 3'].replace({"Singapore Seletar Airport":"Singapore Seletar Airport"+", "+str(distance14)+" km"}, inplace = True)
df2['Stop 3'].replace({"Tanah Merah MRT Station":"Tanah Merah MRT Station"+", "+str(distance5)+" km"}, inplace = True)
df2['Stop 3'].replace({"Johor Bahru Sentral":"Johor Bahru Sentral"+", "+str(distance9)+" km"}, inplace = True)

#Stop 4
#Senai Airport - Johor Bahru Sentral
origin11 = (df1.at[7,"Coordinate"])
stop11 = (df1.at[8,"Coordinate"])
distance9 = int(geodesic(origin11, stop11).km)

#Singapore Seletar Airport - Legoland
origin12 = (df1.at[11,"Coordinate"])
stop12 = (df1.at[3,"Coordinate"])
distance15 = int(geodesic(origin12, stop12).km)

#Tanah Merah MRT Station - Jurong East Station
origin13 = (df1.at[5,"Coordinate"])
stop13 = (df1.at[6,"Coordinate"])
distance6 = int(geodesic(origin13, stop13).km)

#Johor Bahru Sentral - Legoland
origin14 = (df1.at[8,"Coordinate"])
stop14 = (df1.at[3,"Coordinate"])
distance10 = int(geodesic(origin14, stop14).km)


#can but no change
df2['Stop 4'].replace({'Johor Bahru Sentral':'Johor Bahru Sentral'+',' +str(distance9)+" km"}, inplace = True)
df2['Stop 4'].replace({"Legoland":"Legoland"+", "+str(distance15)+" km"}, inplace = True)
df2['Stop 4'].replace({"Jurong East Station":"Jurong East Station"+", "+str(distance6)+" km"}, inplace = True)
df2['Stop 4'].replace({" Legoland":"Legoland"+", "+str(distance10)+" km"}, inplace = True)


#Stop 5
#Johor Bahru Sentral - Legoland
origin15 = (df1.at[8,"Coordinate"])
stop15 = (df1.at[3,"Coordinate"])
distance10 = int(geodesic(origin15, stop15).km)

#Jurong East Station - Legoland
origin16 = (df1.at[6,"Coordinate"])
stop16 = (df1.at[3,"Coordinate"])
distance7 = int(geodesic(origin16, stop16).km)


#can
#df2['Stop 5'].replace({"Nan":"Nan"},inplace = True)
df2['Stop 5'].replace({"Legoland":"Legoland"+", "+str(distance10)+" km"}, inplace = True)
#df2['Stop 5'].replace({"Nan":"Nan"}, inplace = True)
df2['Stop 5'].replace({" Legoland":"Legoland"+", "+str(distance7)+" km"}, inplace = True)
#df2['Stop 5'].replace({"Nan":"Nan"}, inplace = True)
print(">>>>>>>>>>>>TASK 1<<<<<<<<<<<")

display(df1)

print(">>>>>>>>>>>>>>>TASK 2<<<<<<<<<<<<<")

display(df2)



  
#TASK 3 : FIND BEST ROUTE USING DIJKSTRA ALGORITHM
graph = {'KL Sentral':{'KLIA':42,'KTM Skypark':14},'KLIA':{'TUTA':256,'Changi':247,'Senai':250},
         'TUTA':{'Legoland':10},'Changi':{'MRT Tanah Merah':5},'MRT Tanah Merah':{'Jurong':26}
         ,'Jurong':{'Legoland':15},'Senai':{'JBS':22},'JBS':{'Legoland':15},
         'KTM Skypark':{'Subang Airport':0},'Subang Airport':{'Senai':287,'Seletar':314},
         'Seletar':{'Legoland':26},'Legoland':{'Seletar':26}}

def dijkstra(graph,start,goal):
    shortest_distance = {}
    predecessor = {}
    unseenNodes = graph
    infinity = 9999999
    path = []
    for node in unseenNodes:
        shortest_distance[node] = infinity
    shortest_distance[start] = 0
 
    while unseenNodes:
        minNode = None
        for node in unseenNodes:
            if minNode is None:
                minNode = node
            elif shortest_distance[node] < shortest_distance[minNode]:
                minNode = node
 
        for childNode, weight in graph[minNode].items():
            if weight + shortest_distance[minNode] < shortest_distance[childNode]:
                shortest_distance[childNode] = weight + shortest_distance[minNode]
                predecessor[childNode] = minNode
        unseenNodes.pop(minNode)
 
    currentNode = goal
    while currentNode != start:
        try:
            path.insert(0,currentNode)
            currentNode = predecessor[currentNode]
        except KeyError:
            print('Path not reachable')
            break
    path.insert(0,start)
    if shortest_distance[goal] != infinity:
        print('Shortest distance is ' + str(shortest_distance[goal]))
        print('And the path is ' + str(path))
        
print(">>>>>>>>>>>>>>>>TASK 3<<<<<<<<<<<<<<<<")

print(dijkstra(graph, "KL Sentral", "Legoland"))

print()

#TASK 4 : PLOTTING ROUTE

import gmaps
#import googlemaps
from gmplot import gmplot
#gmaps = googlemaps.Client(api_key)
gmap = gmplot.GoogleMapPlotter(2.64, 102.803, 7)

gmap.scatter(df1['Latitude'],df1['Longitude'], '#FFFFFF', size=100, marker=False)
gmap.draw('maptest.html')

lat = df1["Latitude"].tolist()
lng = df1["Longitude"].tolist()

route0_lat = [lat[0],lat[1],lat[2],lat[3]]
route0_lng = [lng[0],lng[1],lng[2],lng[3]]
gmap.plot(route0_lat, route0_lng, "white", edge_width = 3.0)

route1_lat = [lat[0],lat[9],lat[10],lat[7],lat[8],lat[3]]
route1_lng = [lng[0],lng[9],lng[10],lng[7],lng[8],lng[3]]
gmap.plot(route1_lat, route1_lng, "blue", edge_width = 3.0)

route2_lat = [lat[0],lat[9],lat[10],lat[11],lat[3]]
route2_lng = [lng[0],lng[9],lng[10],lng[11],lng[3]]
gmap.plot(route2_lat, route2_lng, "green", edge_width = 3.0)

route3_lat = [lat[0],lat[1],lat[4],lat[5],lat[6],lat[3]]
route3_lng = [lng[0],lng[1],lng[4],lng[5],lng[6],lng[3]]
gmap.plot(route3_lat, route3_lng, "red", edge_width = 3.0)

route4_lat = [lat[0],lat[1],lat[7],lat[8],lat[3]]
route4_lng = [lng[0],lng[1],lng[7],lng[8],lng[3]]
gmap.plot(route4_lat, route4_lng, "yellow", edge_width = 3.0)


gmap.draw('Polyline.html')

print(">>>>>>>>>>>>>>>>>>TASK 4<<<<<<<<<<<<<<<")

print("-------Open file Polyline.html to see the illustration of the routes--------")
# Out:
# --------------------------------- PROBLEM 1 ---------------------------------
# >>>>>>>>>>>>TASK 1<<<<<<<<<<<
#                                location  \
# 0                            KL Sentral
# 1    Kuala Lumpur International Airport
# 2   Taman Ungku Tun Aminah Bus Terminal
# 3                     Legoland Malaysia
# 4          Changi International Airport
# 5                   Tanah Merah Station
# 6                    Jurong MRT Station
# 7           Senai International Airport
# 8                   Johor Bahru Sentral
# 9                      Terminal Skypark
# 10       Sultan Abdul Aziz Shah Airport
# 11                      Seletar Airport
#
#                                               Address  Latitude   Longitude  \
# 0   (MR1 KL Sentral (Monorail), Jalan Thambipillay...  3.132590  101.688001
# 1   (Lapangan Terbang Antarabangsa Kuala Lumpur, L...  2.745524  101.701507
# 2   (Taman Ungku Tun Aminah, Iskandar Puteri, Joho...  1.519677  103.661410
# 3   (Legoland Malaysia, Jalan Legoland, Medini, Is...  1.426597  103.629046
# 4   (Singapore Changi Airport, Alps Avenue, Airpor...  1.354884  103.988013
# 5   (Tanah Merah Station, New Upper Changi Road, S...  1.327309  103.945765
# 6   (Boon Lay, Boon Lay Way, Jurong West, Southwes...  1.338575  103.705848
# 7   (Lapangan Terbang Antarabangsa Senai, Jalan Ju...  1.640755  103.666768
# 8   (Johor Bahru Sentral, Komtar JBCC - Johor Bahr...  1.462974  103.764634
# 9   (Terminal Skypark, Jalan Lapangan Terbang Suba...  3.134365  101.555391
# 10  (Lapangan Terbang Sultan Abdul Aziz Shah, Jala...  3.131711  101.550926
# 11  (Seletar Airport, Seletar Aerospace Rise, Sele...  1.417020  103.868082
#
#                        Coordinate
# 0   3.13259005,101.68800109413272
# 1     2.74552395,101.701506799265
# 2           1.5196767,103.6614104
# 3    1.4265973,103.62904636694924
# 4    1.3548836,103.98801277346743
# 5           1.3273087,103.9457655
# 6           1.3385752,103.7058478
# 7   1.64075465,103.66676752978722
# 8           1.4629737,103.7646343
# 9    3.1343654,101.55539060029545
# 10  3.13171145,101.55092565436746
# 11   1.4170202,103.86808181112622
# >>>>>>>>>>>>>>>TASK 2<<<<<<<<<<<<<
#        Origin                                     Stop 1  \
# 0  KL Sentral  Kuala Lumpur International Airport, 42 km
# 1  KL Sentral    Terminal Skypark Komuter Station, 14 km
# 2  KL Sentral    Terminal Skypark Komuter Station, 14 km
# 3  KL Sentral  Kuala Lumpur International Airport, 42 km
# 4  KL Sentral  Kuala Lumpur International Airport, 42 km
#
#                                  Stop 2                             Stop 3  \
# 0                 Terminal TUTA, 256 km                    Legoland, 10 km
# 1  Sultan Abdul Aziz Shah Airport, 0 km              Senai Airport, 287 km
# 2  Sultan Abdul Aziz Shah Airport, 0 km  Singapore Seletar Airport, 319 km
# 3                Changi Airport, 297 km      Tanah Merah MRT Station, 5 km
# 4                 Senai Airport, 250 km         Johor Bahru Sentral, 22 km
#
#                        Stop 4           Stop 5
# 0                         NaN              NaN
# 1   Johor Bahru Sentral,22 km  Legoland, 15 km
# 2             Legoland, 26 km              NaN
# 3  Jurong East Station, 26 km  Legoland, 12 km
# 4             Legoland, 15 km              NaN
# >>>>>>>>>>>>>>>>TASK 3<<<<<<<<<<<<<<<<
# Shortest distance is 308
# And the path is ['KL Sentral', 'KLIA', 'TUTA', 'Legoland']
# None
#
# >>>>>>>>>>>>>>>>>>TASK 4<<<<<<<<<<<<<<<
# -------Open file Polyline.html to see the illustration of the routes--------

# %%
print("--------------------------------- PROBLEM 2 ---------------------------------")

import string

import plotly
import plotly.graph_objects as go

filesArr = ["bus1.txt", "plane1.txt", "kliaexpress1.txt", "taxi1.txt", "ktm1.txt", "rapidkl1.txt", "smrt1.txt"]
posArr = ["posbus.txt", "posplane.txt", "posklia.txt", "postaxi.txt", "posktm.txt", "posrapid.txt", "posmrt.txt"]  # store stopwords for each text file
stopWords = "stopwords.txt"
wordCount_before = [0, 0, 0, 0, 0, 0, 0]
wordCount_after = [0, 0, 0, 0, 0, 0, 0]


# Method for remove stop words from each text file
def removeStopwords(list1, stopwords):
    return [w for w in list1 if w not in stopwords]


print("\nSTOP WORDS REMOVAL:\n")

index = 0
for i in range(0, len(filesArr), 1):
    fileDirectory = filesArr[index]
    posDirectory = posArr[index]

    # Count total words before stop words removal
    totalCount = 0
    with open(fileDirectory, "r+", encoding="utf8") as word_list:
        words = word_list.read()

        totalCount = len(words)

        print("Total word count of {0} before stop words removal: {1}".format(
            filesArr[index], totalCount))
        wordCount_before[index] = totalCount

        # file with stopwords
        f1 = open(stopWords, "r+", encoding="utf8")

        # transport text file
        f2 = open(fileDirectory, "r+", encoding="utf8")

        file1_raw = f1.read()
        file2_raw = f2.read().lower()

        sw = file1_raw.split()
        file2_words_SWRemoved = file2_raw.split()

        # Remove punctuations
        pc = string.punctuation
        pc += '""''-'
        table = str.maketrans('', '', pc)
        stripped = [w.translate(table) for w in file2_words_SWRemoved]

        # Remove stop words
        wordlist2 = removeStopwords(stripped, sw)

        # Write edited text file content back
        f2_w = open(posDirectory, "w", encoding="utf8")
        f2_w.write(" ".join(wordlist2))
        f2_w.close()
        f1.close()
        f2.close()
        #print(f)

        # Count total words in each transportation stop word file
        totalCount1 = 0
        with open(posDirectory, "r+", encoding="utf8") as list:
            words1 = list.read().lower().split()

        totalCount1 = len(words1)

        print("Total word count of {0} after stop words removal: {1}".format(
            filesArr[index], totalCount1))
        print(wordlist2)
        print("\n")
        wordCount_after[index] = totalCount1
        index = index + 1

# PROBLEM 2.6: Plot line/scatter/histogram using Plotly (Word Count, stop words)

x = ["Bus", "Plane", "KLIA Express", "Taxi", "KTM", "Rapid KL", "SMRT"]
z = [str(wordCount_after[0]), str(wordCount_after[1]), str(wordCount_after[2]), str(wordCount_after[3]),
     str(wordCount_after[4]), str(wordCount_after[5]), str(wordCount_after[6])]
y = [str(wordCount_before[0]), str(wordCount_before[1]), str(wordCount_before[2]), str(wordCount_before[3]),
     str(wordCount_before[4]), str(wordCount_before[5]), str(wordCount_before[6])]

fig = go.Figure()
fig.add_trace(go.Histogram(histfunc="sum", y=y, x=x, name="Word count"))
fig.add_trace(go.Histogram(histfunc="sum", y=z, x=x, name="Stop words"))

plotly.offline.plot(fig)

# PROBLEM 2.7: Negative/Positive words in article
transport = ["Bus", "Plane", "KLIA Express", "Taxi", "KTM", "Rapid KL", "SMRT"]
filesArr1 = ["bus1.txt", "plane1.txt", "kliaexpress1.txt", "taxi1.txt", "ktm1.txt", "rapidkl1.txt", "smrt1.txt"]

positiveCountArr = [0, 0, 0, 0, 0, 0, 0]
negativeCountArr = [0, 0, 0, 0, 0, 0, 0]
sentimentCountArr = [0, 0, 0, 0, 0, 0, 0]


# Compare method

def positiveCompare(file, posfile):
    return [w for w in file if w in posfile]


def negativeCompare(file, negfile):
    return [w for w in file if w in negfile]


print("-------------------POS/NEG COUNTER :------------------------\n")

index = 0
for i in range(0, len(filesArr), 1):
    fileDirect = filesArr1[index]

    # Count total words
    totalCount = 0
    with open(fileDirect, "r+", encoding="utf8") as word_list:
        words = word_list.read()

        totalCount = len(words)

        pos = open("positive.txt", encoding="utf8")
        pos = pos.read().split()
        neg = open("negative.txt", encoding="utf8")
        neg = neg.read().split()

        file1 = open(fileDirect, encoding='utf8')
        file1 = file1.read().lower().split()

        positiveCount = 0
        negativeCount = 0
        neutral = 0

        poswordlist = positiveCompare(file1, pos)
        positiveCount = len(poswordlist)

        negwordlist = negativeCompare(file1, neg)
        negativeCount = len(negwordlist)

        neutral = totalCount - (positiveCount - negativeCount)
        sentiment = (positiveCount - negativeCount)/100

        print("Total Number of Positive Words in {0}: {1}".format(filesArr1[index], positiveCount))
        print("Total Number of Negative Words in {0}: {1}".format(filesArr1[index], negativeCount))
        print("Total Number of Neutral Words in {0}: {1}".format(filesArr1[index], neutral))
        print("Sentiment Value in {0}: {1}".format(filesArr1[index], sentiment))
        # Conclusion made
        if positiveCount > negativeCount:
            print("Article Sentiment: Positive\n")
        elif positiveCount < negativeCount:
            print("Article Sentiment: Negative\n")
        else:
            print("Article Sentiment: Neutral\n")


        positiveCountArr[index] = positiveCount
        negativeCountArr[index] = negativeCount
        sentimentCountArr[index] = sentiment

        index = index + 1
        # sort the transportation according to the sentiment value
sentimentArr = {transport[0]: sentimentCountArr[0], transport[1]: sentimentCountArr[1],
                transport[2]: sentimentCountArr[2], transport[3]: sentimentCountArr[3],
                transport[4]: sentimentCountArr[4], transport[5]: sentimentCountArr[5],
                transport[6]: sentimentCountArr[6]}
sentimentArr = sorted(sentimentArr.items(), key=lambda x: x[1], reverse=True)

print('----------------Best Transportation According to Sentiment Value-----------------------')
for i in sentimentArr:
    print(i[0], i[1])

    # GRAPH FOR POSITIVE AND NEGATIVE WORDS

x = ["Bus", "Plane", "KLIA Express", "Taxi", "KTM", "Rapid KL", "SMRT"]
y = [str(positiveCountArr[0]), str(positiveCountArr[1]), str(positiveCountArr[2]), str(positiveCountArr[3]),
     str(positiveCountArr[4]), str(positiveCountArr[5]), str(positiveCountArr[6])]
z = [str(negativeCountArr[0]), str(negativeCountArr[1]), str(negativeCountArr[2]), str(negativeCountArr[3]),
     str(negativeCountArr[4]), str(negativeCountArr[5]), str(negativeCountArr[6])]

fig1 = go.Figure()
fig1.add_trace(go.Histogram(histfunc="sum", y=y, x=x, name="Positive words"))
fig1.add_trace(go.Histogram(histfunc="sum", y=z, x=x, name="Negative words"))

plotly.offline.plot(fig1)
# Out:
# --------------------------------- PROBLEM 2 ---------------------------------
#
# STOP WORDS REMOVAL:
#
# Total word count of bus1.txt before stop words removal: 5104
# Total word count of bus1.txt after stop words removal: 501
# ['search', 'covid19', 'advertise', 'malay', 'mail', 'home', 'malaysia', 'singapore', 'world', 'money', 'life', 'eatdrink', 'showbiz', 'wyt', 'opinion', 'sports', 'techgadgets', 'drive', 'videos', 'archives', 'privacy', 'policy', 'terms', 'advertise', 'apple', 'appstore', 'google', 'play', 'store', 'huawei', 'app', 'gallery', 'google', 'news', 'projekmm', '精彩大马', 'covid19', 'home', 'malaysia', 'singapore', 'world', 'money', 'life', 'eatdrink', 'showbiz', 'opinion', 'sports', 'techgadgets', 'drive', 'videos', 'projekmm', '精彩大马', 'loading', 'home', 'malaysia', 'transport', 'ministry', 'reiterates', 'operation', 'hours', 'public', 'transport', 'tuesday', '24', 'mar', '2020', '0534', 'pm', 'myt', 'john', 'bunyan', 'image', 'people', 'seen', 'practising', 'social', 'distancing', 'lrt', 'ride', 'kuala', 'lumpur', 'march', '24', '2020', '—', 'bernama', 'pic', 'people', 'seen', 'practising', 'social', 'distancing', 'lrt', 'ride', 'kuala', 'lumpur', 'march', '24', '2020', '—', 'bernama', 'pic', 'kuala', 'lumpur', 'march', '24', '—', 'transport', 'minister', 'datuk', 'seri', 'wee', 'ka', 'siong', 'reiterated', 'daily', 'operational', 'hours', 'public', 'transport', '6am', '10am', '5pm', '10pm', 'nationwide', 'effective', 'march', '25', 'entire', 'duration', 'movement', 'control', 'mco', 'wee', 'affected', 'land', 'public', 'transport', 'modes', 'stage', 'buses', 'free', 'buses', 'gokl', 'smart', 'selangor', 'feeder', 'buses', 'rail', 'services', 'lrt', 'mrt', 'monorail', 'erl', 'ktmb', '“the', 'ministry', 'recognises', 'public', 'transport', 'mode', 'transportation', 'public', 'especially', 'b40', '“this', 'decision', 'difficult', 'ensure', 'mco', 'implemented', 'effectively', 'line', 'goal', 'breaking', 'covid19', 'pandemic', 'chain', 'preventing', 'people', 'assembling', 'including', 'public', 'transport', 'stops', 'stations', 'terminals”', 'wrote', 'facebook', 'post', 'yesterday', 'senior', 'minister', 'datuk', 'seri', 'ismail', 'sabri', 'yaakob', 'announced', 'government', 'restricted', 'daily', 'operational', 'hours', 'public', 'transport', '6am', '10am', '5pm', '10pm', 'due', 'drop', 'passenger', 'following', 'enforcement', 'mco', 'wee', 'stressed', 'taxi', 'ehailing', 'services', 'continue', 'operate', 'usual', 'accordance', 'predefined', 'guidelines', 'wee', 'explained', 'operational', 'hours', 'enforced', 'reports', 'decrease', 'percentage', 'passengers', 'using', 'public', 'transport', 'mco', 'effect', 'march', '18', '“for', 'stage', 'buses', 'free', 'buses', 'feeder', 'buses', 'shown', 'total', '9163', 'cent', 'decrease', 'passengers', '“on', 'march', '16', 'modes', 'transportation', 'recorded', 'total', '233500', 'passengers', 'march', '22', 'dropped', 'drastically', '19540', 'passengers', 'due', 'mco”', 'ktm', 'komuter', 'recorded', 'average', 'decrease', '8925', 'cent', 'march', '18', 'march', '22', '“from', '6am', '10am', 'passengers', 'gone', '35050', '3768', '10am', '5pm', 'declined', '11683', '1256', 'passengers', '5pm', '10pm', 'dropped', '31156', '3350', 'passengers”', 'rapid', 'rail', 'includes', 'lrt', 'mrt', 'monorail', 'services', 'recorded', 'decrease', '9509', 'cent', '578716', 'passengers', 'march', '16', '28409', 'passengers', 'march', '20', 'meanwhile', 'erl', 'recorded', 'drop', '8708', 'cent', 'passengers', 'decreasing', '14642', '1892', 'period', 'stated', 'wee', 'bus', 'services', 'peninsula', 'malaysia', 'operation', 'aim', 'providing', 'limited', 'access', 'individuals', 'involved', 'providing', 'essential', 'services', '“the', 'ministry', 'directed', 'express', 'bus', 'operators', 'stop', 'service', '“however', 'ministry', 'obstruction', 'event', 'express', 'bus', 'operators', 'forced', 'reduce', 'trips', 'plan', 'temporarily', 'suspend', 'services', 'mco', 'period', 'demand', 'dropped', 'sharply', 'express', 'bus', 'services”', 'wee', 'ministry', 'governments', 'monitor', 'developments', 'terminals', 'roads', 'action', 'time', 'time', '“i', 'advise', 'people', 'leave', 'house', 'unless', 'absolutely', ...
#
#
# Total word count of plane1.txt before stop words removal: 11593
# Total word count of plane1.txt after stop words removal: 1120
# ['subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'starplus', 'news', 'asean', 'business', 'sport', 'metro', 'lifestyle', 'food', 'tech', 'education', 'opinion', 'videos', 'photos', 'subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'badminton', 'golf', 'community', 'sports', 'tennis', 'motorsport', 'sport', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'letters', 'columnists', 'videos', 'photos', 'star', 'mall', 'classifieds', 'starcherishcom', 'events', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'golf', 'badminton', 'tennis', 'motorsport', 'community', 'sports', 'sports', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'columnists', 'letters', 'videos', 'photos', 'star', 'mall', 'classifieds', 'events', 'starcherishcom', 'topics', '', 'grounded', 'airlines', 'malaysia', 'skies', 'help', 'covid19', 'frontliners', 'malaysia', 'thursday', '02', 'apr', '2020', '805', 'am', 'myt', 'chester', 'chin', 'malaysia', 'airlines', 'standby', 'klia', 'mobilise', 'medical', 'staff', 'professionals', 'country', 'airasia', 'temporary', 'hibernation', 'customers', 'safe', '—', 'azhar', 'mahfofthe', 'star', 'world', 'airlines', 'forced', 'deal', 'devastating', 'effects', 'ongoing', 'global', 'outbreak', 'covid19', 'effectively', 'brought', 'travel', 'industry', 'standstill', 'countries', 'close', 'borders', 'restrict', 'travel', 'minimise', 'spread', 'novel', 'coronavirus', 'carriers', 'reducing', 'network', 'operations', 'temporarily', 'grounding', 'aircraft', 'visitors', 'airports', 'malaysia', 'kuala', 'lumpur', 'international', 'airport', 'klia', 'klia2', 'greeted', 'extremely', 'rare', 'sight', 'aprons', 'tarmac', 'occupied', 'dozens', 'grounded', 'aircraft', 'malaysian', 'aviation', 'commission', 'mavcom', 'air', 'travel', 'country', 'predicted', 'decrease', 'significantly', 'due', 'global', 'outbreak', 'covid19', 'revised', 'estimate', 'commission', 'passenger', 'traffic', '677', 'million', '697', 'million', 'passengers', 'considerable', 'decrease', 'year’s', 'alltime', '1092', 'million', 'passengers', 'mavcom', 'executive', 'chairman', 'dr', 'nungsari', 'ahmad', 'radhi', 'aviation', 'sector', 'facing', 'huge', 'blow', 'crisis', '“aviation', 'worst', 'hit', 'industry', 'global', 'covid19', 'outbreak', 'travel', 'stopped', 'forcing', 'airlines', 'essentially', 'grounded', 'thereby', 'putting', 'serious', 'financial', 'distress', '”', 'figures', 'mavcom', 'existing', 'flight', 'cancellations', 'malaysian', 'foreign', 'carriers', 'totalled', '14', 'million', 'seats', 'period', 'january', 'december', '2020', 'image', 'kl', 'i ...
#
#
# Total word count of kliaexpress1.txt before stop words removal: 6281
# Total word count of kliaexpress1.txt after stop words removal: 670
# ['subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'starplus', 'news', 'asean', 'business', 'sport', 'metro', 'lifestyle', 'food', 'tech', 'education', 'opinion', 'videos', 'photos', 'subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'badminton', 'golf', 'community', 'sports', 'tennis', 'motorsport', 'sport', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'letters', 'columnists', 'videos', 'photos', 'star', 'mall', 'classifieds', 'starcherishcom', 'events', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'golf', 'badminton', 'tennis', 'motorsport', 'community', 'sports', 'sports', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'columnists', 'letters', 'videos', 'photos', 'star', 'mall', 'classifieds', 'events', 'starcherishcom', 'topics', '', 'klia', 'ekspres', 'resumes', 'train', 'service', 'airport', 'passengers', 'maintain', '1m', 'distance', 'malaysia', 'wednesday', '06', '2020', '110', 'pm', 'myt', 'chester', 'chin', 'klia', 'express', 'klia', 'transit', 'train', 'services', 'start', 'operating', 'introduce', 'limited', 'service', 'schedule', 'month', '', 'filepic', 'klia', 'ekspres', 'klia', 'transit', 'train', 'services', 'start', 'operating', 'introduce', 'limited', 'service', 'schedule', 'month', 'starting', '4', 'trains', 'run', '20', 'minutes', 'peak', 'hours', 'weekdays', '30', 'minutes', 'offpeak', 'hours', 'weekends', 'national', 'public', 'holidays', '“the', 'schedule', 'reviewed', 'adjusted', 'suit', 'growing', 'passenger', 'ridership', 'schedule', 'published', 'five', 'days', 'prior', 'implementation', 'consultation', 'approval', 'relevant', 'authorities”', 'express', 'rail', 'link', 'erl', 'statement', 'posted', 'website', 'klia', 'ekspres', 'klia', 'transit', 'run', 'combined', 'service', 'train', 'services', '6am', 'train', 'departure', '11pm', 'period', 'passengers', 'follow', 'social', 'distancing', 'safety', 'measures', 'curb', 'covid19', 'include', 'body', 'temperature', 'check', 'wearing', 'masks', 'cashless', 'payment', 'passenger', 'body', 'temperature', '375⁰c', 'denied', 'entry', 'addition', 'passengers', 'strongly', 'advised', 'wear', 'mask', 'times', 'using', 'train', 'service”', 'erl', 'passengers', 'urged', 'safe', 'distance', '1m', 'apart', 'times', 'including', 'platform', 'onboard', 'train', 'additionally', 'passengers', 'encouraged', 'avoid', 'paying', 'cash', 'instead', 'cashless', 'buying', 'tickets', 'contactless', 'cards', 'touch', '‘n', 'directly', 'gate', 'pay', 'preferred', 'ewallet', 'counter”', 'erl', 'adding', 'standard', 'tickets', 'bought', 'selfservice', 'kiosk', 'jour ...
#
#
# Total word count of taxi1.txt before stop words removal: 11248
# Total word count of taxi1.txt after stop words removal: 1099
# ['subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'starplus', 'news', 'asean', 'business', 'sport', 'metro', 'lifestyle', 'food', 'tech', 'education', 'opinion', 'videos', 'photos', 'subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'badminton', 'golf', 'community', 'sports', 'tennis', 'motorsport', 'sport', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'letters', 'columnists', 'videos', 'photos', 'star', 'mall', 'classifieds', 'starcherishcom', 'events', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'golf', 'badminton', 'tennis', 'motorsport', 'community', 'sports', 'sports', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'columnists', 'letters', 'videos', 'photos', 'star', 'mall', 'classifieds', 'events', 'starcherishcom', 'topics', '', 'taxi', 'ehailing', 'drivers', 'loss', 'metro', 'news', 'wednesday', '08', 'apr', '2020', 'bavani', 'edward', 'rajendra', 'aida', 'ahmad', 'taxi', 'dropoff', 'tbs', 'station', 'bandar', 'tasik', 'selatan', 'empty', '—', 'photos', 'low', 'lay', 'phonthestar', 'times', 'hard', 'worth', 'sentiment', 'taxi', 'ehailing', 'drivers', 'klang', 'valley', 'start', 'movement', 'control', 'mco', 'month', 'finding', 'hard', 'meet', 'drivers', 'unsure', 'staying', 'home', 'spending', 'sparingly', 'waiting', 'passengers', 'designated', 'stops', 'day', 'hoping', 'lady', 'luck', 'shine', 'starmetro', 'speaks', 'hardhit', 'drivers', 'coping', 'temporarily', 'quitting', 'ehailing', 'driver', 'rasamany', 'vettivelu', '73', 'mco', 'effect', 'march', '18', 'weeks', 'able', 'extra', 'money', 'buy', 'groceries', 'provide', 'husband', 'rm500', 'pocket', 'money', 'earning', 'rm2000', 'month', 'ehailing', 'driver', 'days', 'meals', 'home', 'downgraded', 'vegetable', 'curry', 'papadom', '“i', 'am', 'exaggerating', 'merely', 'honest', 'monthly', 'pension', 'goes', 'towards', 'paying', 'utility', 'bills', 'expenses’’', 'retired', 'inland', 'revenue', 'board', 'officer', 'rasamany', 'forced', 'job', 'ago', 'lost', 'huge', 'chunk', 'savings', '82yearold', 'husband’s', 'gold', 'investment', 'company', '“the', 'driving', 'job', 'pay', 'husband', 'month', 'pay', 'petrol’’', 'staying', 'home', 'plain', 'reason', 'infected', 'covid19', '55yearold', 'taxi', 'driver', 'jambulingam', 'klang', 'taman', 'sentosa', 'taxi', 'hired', 'car', 'drivers', 'welfare', 'association', 'president', 'people', 'avoid', 'getting', 'taxis', 'third', 'day', 'mco', '“awareness', 'covid19', 'heightened', 'third', 'day', 'people', 'social', 'distancing', '“our', 'regular', 'passengers', 'politely', 'told', 'walk', 'cycle', 'groceries', '“ma ...
#
#
# Total word count of ktm1.txt before stop words removal: 5554
# Total word count of ktm1.txt after stop words removal: 615
# ['subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'starplus', 'news', 'asean', 'business', 'sport', 'metro', 'lifestyle', 'food', 'tech', 'education', 'opinion', 'videos', 'photos', 'subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'badminton', 'golf', 'community', 'sports', 'tennis', 'motorsport', 'sport', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'letters', 'columnists', 'videos', 'photos', 'star', 'mall', 'classifieds', 'starcherishcom', 'events', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'golf', 'badminton', 'tennis', 'motorsport', 'community', 'sports', 'sports', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'columnists', 'letters', 'videos', 'photos', 'star', 'mall', 'classifieds', 'events', 'starcherishcom', 'topics', '', 'covid19', 'ktm', 'reducing', 'frequency', 'trains', 'mco', 'nation', 'sunday', '22', 'mar', '2020', '1203', 'am', 'myt', 'petaling', 'jaya', 'keretapi', 'tanah', 'melayu', 'bhd', 'ktm', 'reducing', 'frequency', 'train', 'services', 'duration', 'movement', 'control', 'mco', 'according', 'ktm', 'chief', 'executive', 'officer', 'datuk', 'kamarulzaman', 'zainal', 'electric', 'train', 'services', 'ets', 'ktm', 'komuter', 'skypark', 'link', 'intercity', 'train', 'services', 'affected', 'kamarulzaman', 'reduction', 'daily', 'trips', '–', 'ets', 'eight', 'compared', '40', 'daily', 'trips', 'ktm', 'intercity', 'reduction', '10', 'trips', '18', 'ktm', 'komuter', 'reduced', '208', '164', 'daily', 'trips', 'commuter', 'operations', 'weekdays', 'reduced', '138', 'compared', '167', 'daily', 'trips', 'tebrau', 'shuttle', 'operates', 'johor', 'bahru', 'sentral', 'station', 'woodlands', 'station', 'singapore', 'reduced', 'eight', 'trips', 'day', 'compared', '31', 'kamarulzaman', 'press', 'release', 'late', 'saturday', 'march', '21', 'kamarulzaman', 'skypark', 'link', 'train', 'kl', 'sentral', 'station', 'subang', 'airport', 'reduced', 'eight', 'trips', 'day', 'compared', '32', 'according', 'kamarulzaman', 'reduction', 'trips', 'comply', 'governments', 'directive', 'reduce', 'interstate', 'travel', 'takes', 'account', 'drastic', 'drop', 'passengers', 'meanwhile', 'kamarulzaman', 'passengers', 'amendments', 'cancel', 'tickets', 'counter', 'official', 'website', 'wwwktmbcommy', 'urged', 'public', 'obtain', 'information', 'regarding', 'train', 'operations', 'ktms', 'official', 'website', 'call', 'hotline', '0322671200', 'twoweek', 'mco', 'imposed', 'government', 'march', '18', 'march', '31', 'article', 'type', 'free', 'user', 'access', 'status', 'tags', '', 'keywords', 'covid19', '', 'coronavirus',  ...
#
#
# Total word count of rapidkl1.txt before stop words removal: 6468
# Total word count of rapidkl1.txt after stop words removal: 694
# ['subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'starplus', 'news', 'asean', 'business', 'sport', 'metro', 'lifestyle', 'food', 'tech', 'education', 'opinion', 'videos', 'photos', 'subscriptions', 'star', 'digital', 'access', 'newsstand', 'sms', 'services', 'log', 'manage', 'profile', 'change', 'password', 'manage', 'subscription', 'manage', 'billing', 'info', 'transaction', 'history', 'manage', 'manage', 'bookmarks', 'package', '', 'pricing', 'faqs', 'log', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'badminton', 'golf', 'community', 'sports', 'tennis', 'motorsport', 'sport', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'letters', 'columnists', 'videos', 'photos', 'star', 'mall', 'classifieds', 'starcherishcom', 'events', 'home', 'starplus', 'news', 'nation', 'world', 'environment', 'media', 'true', 'focus', 'asean', 'business', 'news', 'smebiz', 'unit', 'trust', 'exchange', 'rates', 'portfolio', 'market', 'watch', 'bursa', 'overview', 'market', 'movers', 'financial', 'results', 'dividends', 'bonus', 'ipo', 'sport', 'football', 'golf', 'badminton', 'tennis', 'motorsport', 'community', 'sports', 'sports', 'metro', 'metro', 'news', 'views', 'lifestyle', 'entertainment', '', 'style', 'people', '', 'living', 'health', '', 'family', 'travel', '', 'culture', 'food', 'food', 'news', 'eating', 'kuali', 'tech', 'education', 'news', 'courses', 'opinion', 'columnists', 'letters', 'videos', 'photos', 'star', 'mall', 'classifieds', 'events', 'starcherishcom', 'topics', '', 'rapid', 'kl', 'taking', 'shortcuts', 'nation', 'saturday', '08', 'feb', '2020', 'taking', 'precautions', 'housekeeping', 'personnel', 'akter', 'husen', 'left', 'shopon', 'husen', 'cleaning', 'inside', 'bus', 'stem', 'spread', 'virus', 'outbreak', 'rapid', 'bus', 'depot', 'cheras', 'kuala', 'lumpur', '—', 'bernama', 'kuala', 'lumpur', 'rapid', 'kl', 'extra', 'steps', 'minimise', 'risk', 'exposure', 'novel', 'coronavirus', 'infection', 'million', 'passengers', 'commute', 'bus', 'train', 'services', 'daily', 'company', 'set', 'routine', 'morning', 'health', 'checks', 'bus', 'captains', 'deployed', 'respective', 'routes', 'move', 'safeguard', 'wellbeing', 'staff', 'rapid', 'bus', 'chief', 'executive', 'officer', 'muhammad', 'yazurin', 'sallij', 'mandatory', 'checking', 'temperatures', 'health', 'conditions', 'bus', 'captains', 'conducted', 'morning', 'routine', 'started', 'third', 'week', 'month', '“we', 'brief', 'bus', 'captains', 'provide', 'information', 'virus', 'terms', 'symptoms', 'look', 'standard', 'operating', 'procedures', 'emergency', 'situation', 'involving', 'customers', '“this', 'routine', 'morning', 'seven', 'rapid', 'kl', 'depots', 'rapid', 'penang', 'rapid', 'kuantan', 'rapid', 'kamunting', 'rapid', 'manjung', '”', 'told', 'press', 'conference', 'kompleks', 'rapid', 'bus', 'cheras', 'selatan', 'yesterday', 'muhammad', 'yazurin', 'bus', 'captains', 'provided', 'masks', 'fit', 'healthy', 'allowed', 'proceed', 'driving', 'duties', 'unwell', 'advised', 'seek', 'medical', 'treatment', 'immediately', 'h\u200band', 'sanitisers', 'provided', 'passengers', 'board', 'rapid', 'kl', 'airport', 'shuttle', 'service', 'buses', 'klia', 'klia2', 'buses', 'heading', 'airports', 'added', 'meanwhile', 'additional', 'measures', 'rapid', 'rail', 'public', 'service', 'announcements', 'cor ...
#
#
# Total word count of smrt1.txt before stop words removal: 6594
# Total word count of smrt1.txt after stop words removal: 613
# ['skip', 'navigation', 'jump', 'main', 'main', 'navigation', 'meta', 'navigation', 'home', 'image', 'cna', 'image', 'cna', 'location', 'navigation', 'edition', 'selection', 'meta', 'main', 'navigation', 'news', 'feed', 'bookmarks', 'watch', 'tv', 'cna938', 'live', 'sign', 'user', 'menu', 'profile', 'news', 'feed', 'topics', 'bookmarks', 'merewards', 'cashback', 'coupons', 'surveys', 'merewards', 'coupon', 'deals', 'earn', 'cashback', 'complete', 'surveys', 'dine', 'travel', 'shop', 'partners', 'search', 'section', 'navigation', 'title', 'sg', 'votes', 'cna938', 'cna', 'lifestyle', 'cna', 'insider', 'singapore', 'asia', 'world', 'business', 'sport', 'commentary', 'news', 'clips', 'vod', 'podcasts', 'singapore', '20', 'smrt', 'buses', 'retrofitted', 'help', 'transport', 'covid19', 'patients', 'facilities', 'jump', 'top', 'search', 'main', 'navigation', 'section', 'navigation', 'title', 'home', 'sg', 'votes', 'cna938', 'cna', 'lifestyle', 'cna', 'insider', 'watch', 'tv', 'cna938', 'live', 'compact', 'layout', 'singapore', 'asia', 'world', 'business', 'sport', 'commentary', 'news', 'clips', 'vod', 'podcasts', 'covid19', 'outbreak', 'cna', 'eyewitness', 'singapore', 'parliament', 'newsletters', 'interactives', 'telegram', 'news', 'service', 'weather', 'psi', 'special', 'reports', 'facebook', 'twitter', 'linkedin', 'youtube', 'rss', 'play', 'store', 'app', 'store', 'advertisement', 'advertisement', 'advertisement', 'advertisement', '20', 'smrt', 'buses', 'retrofitted', 'help', 'transport', 'covid19', 'patients', 'facilities', 'advertisement', 'singapore', '20', 'smrt', 'buses', 'retrofitted', 'help', 'transport', 'covid19', 'patients', 'facilities', 'image', 'covid19', 'bus', 'separator', 'airtight', 'partition', 'comet', 'maxi', 'buses', 'separates', 'passenger', 'section', 'driver', 'emergency', 'door', 'partition', 'drivers', 'photo', 'smrt', 'image', 'zhaki', 'abdullah', 'byline', '', 'smiling', 'zhaki', 'abdullah', '12', '2020', '0357pm', 'updated', '12', '2020', '0403pm', 'share', 'content', 'bookmark', 'singapore', 'twenty', 'buses', 'transport', 'operator', 'smrt', 'retrofitted', 'help', 'mass', 'transfer', 'covid19', 'patients', 'hospitals', 'migrant', 'worker', 'dormitories', 'various', 'community', 'recovery', 'care', 'facilities', 'buses', 'dubbed', 'comet', 'maxis', 'covid19', 'multipassenger', 'enhanced', 'transporters', '30', 'passengers', 'time', 'advertisement', 'advertisement', 'airtight', 'partition', 'separating', 'driver', 'passenger', 'compartment', 'measures', 'minimise', 'risk', 'transmission', 'compartment', 'own', 'independent', 'airconditioning', 'system', 'allows', 'air', 'circulation', 'cabins', 'separated', 'announced', 'smrt', 'tuesday', '12', 'joint', 'media', 'release', 'temasek', 'foundation', 'singaporebased', 'engineering', 'firm', 'hope', 'technik', 'sheares', 'healthcare', 'passengers’', 'compartment', 'equipped', 'negative', 'pressure', 'system', 'hepa', 'filter', 'help', 'ensure', 'clean', 'air', 'filtered', 'passengers’', 'compartment', 'image', 'covid19', 'smrt', 'bus', '20', 'smrt', 'buses', 'retrofitted', 'transport', 'covid19', 'patients', 'photo', 'smrt', 'advertisement', 'advertisement', 'driver’s', 'section', 'includes', 'seats', 'additional', 'passengers', 'paramedics', 'escort', 'officers', 'drivers', 'contact', 'passengers', 'vehicles', 'decontaminated', 'deployment', 'trigen', 'automotive', 'special', 'function', 'vehicle', 'division', 'hope', 'technik', 'responsible', 'engineering', 'design', 'conversion', 'buses', 'operation', '6', 'read', 'grab', 'drivers', 'vehicles', 'smrt', 'unit', 'deployed', 'help', 'health', 'ministry', 'suspect', 'covid19', 'hospital', 'days', 'retrofit', 'bus', 'noted', 'head', 'trigen', 'automotive', 'vic', 'naidu', 'adding', 'reversible', 'speaking', 'media', 'tuesday', 'president', 'smrt', 'roads', 'tan', 'kian', 'heong', 'buses', 'low', 'floors', 'wheelchair', 'accessible', '“we', 'chosen', 'relatively', 'buses', 'reliable', 'road”', 'adding', 'buses ...
# -------------------POS/NEG COUNTER :------------------------
#
# Total Number of Positive Words in bus1.txt: 11
# Total Number of Negative Words in bus1.txt: 14
# Total Number of Neutral Words in bus1.txt: 5107
# Sentiment Value in bus1.txt: -0.03
# Article Sentiment: Negative
#
# Total Number of Positive Words in plane1.txt: 43
# Total Number of Negative Words in plane1.txt: 18
# Total Number of Neutral Words in plane1.txt: 11568
# Sentiment Value in plane1.txt: 0.25
# Article Sentiment: Positive
#
# Total Number of Positive Words in kliaexpress1.txt: 14
# Total Number of Negative Words in kliaexpress1.txt: 9
# Total Number of Neutral Words in kliaexpress1.txt: 6276
# Sentiment Value in kliaexpress1.txt: 0.05
# Article Sentiment: Positive
#
# Total Number of Positive Words in taxi1.txt: 36
# Total Number of Negative Words in taxi1.txt: 28
# Total Number of Neutral Words in taxi1.txt: 11240
# Sentiment Value in taxi1.txt: 0.08
# Article Sentiment: Positive
#
# Total Number of Positive Words in ktm1.txt: 15
# Total Number of Negative Words in ktm1.txt: 19
# Total Number of Neutral Words in ktm1.txt: 5558
# Sentiment Value in ktm1.txt: -0.04
# Article Sentiment: Negative
#
# Total Number of Positive Words in rapidkl1.txt: 35
# Total Number of Negative Words in rapidkl1.txt: 24
# Total Number of Neutral Words in rapidkl1.txt: 6457
# Sentiment Value in rapidkl1.txt: 0.11
# Article Sentiment: Positive
#
# Total Number of Positive Words in smrt1.txt: 18
# Total Number of Negative Words in smrt1.txt: 10
# Total Number of Neutral Words in smrt1.txt: 6586
# Sentiment Value in smrt1.txt: 0.08
# Article Sentiment: Positive
#
# ----------------Best Transportation According to Sentiment Value-----------------------
# Plane 0.25
# Rapid KL 0.11
# Taxi 0.08
# SMRT 0.08
# KLIA Express 0.05
# Bus -0.03
# KTM -0.04
# 'temp-plot.html'

# %%
#PROBLEM 3 ------------------------------------------------------------------------------------------

print("--------------------------------- PROBLEM 3 ---------------------------------")

# pos = {#number of positive
#     "KLIA EXPRESS": 9,
#     "SMRT": 15,
#     "KTM": 10,
#     "BUS": 9,
#     "PLANE": 38,
#     "TAXI": 27,
# }
#
# neg = {#number of negative
#     "KLIA EXPRESS": 8,
#     "SMRT": 7,
#     "KTM": 16,
#     "BUS": 12,
#     "PLANE": 18,
#     "TAXI":28,
# }

routeAtt = {
    "route":[["KL SENTRAL  > KLIA > TERMINAL TUTA > LEGOLAND"],
            ["KL SENTRAL  > TERMINAL SKYPARK KOMUTER STATION > SZB AIRPORT > SENAI AIRPORT > JB SENTRAL  > LEGOLAND"],
            ["KL SENTRAL  > TERMINAL SKYPARK KOMUTER STATION > SZB AIRPORT > SINGAPORE SELETAR > LEGOLAND"],
            ["KL SENTRAL  > KLIA > CHANGI AIRPORT > TANAH MERAH >JURONG EAST > LEGOLAND"],
            ["KL SENTRAL  > KLIA > SENAI AIRPORT > JB SENTRAL > LEGOLAND"]],

    "mode": [["KLIA EXPRESS", "BUS", "BUS"],
             ["KTM", "TAXI", "PLANE","BUS","BUS"],
             ["KTM", "TAXI", "PLANE","TAXI"],
             ["KLIA EXPRESS", "PLANE","SMRT","SMRT","BUS"],
             ["KLIA EXPRESS", "PLANE", "BUS", "BUS"]],
    "distance": [42 + 256 + 10,14 +0 + 287 + 22 + 15,14 + 0 + 319 + 26,42 + 297 + 5 + 22 + 15,42 + 250 + 22 + 15],
    "positive": [0,0,0,0,0],
    "negative": [0,0,0,0,0],
    "score": [0,0,0,0,0]
    }

# positive counter
i = 0;
for x in routeAtt["positive"]:
    total = 0;
    for y in routeAtt["mode"][i]:
        if y == "KLIA EXPRESS":
            total += 9
        elif y == "SMRT":
            total += 15
        elif y == "KTM":
            total += 10
        elif y == "BUS":
            total += 9
        elif y == "PLANE":
            total += 38
        else:   #taxi
            total += 27
    routeAtt["positive"][i]=total;
    i += 1;
#negative counter
i = 0;
for x in routeAtt["negative"]:
    total = 0;
    for y in routeAtt["mode"][i]:
        if y == "KLIA EXPRESS":
            total += 8
        elif y == "SMRT":
            total += 7
        elif y == "KTM":
            total += 16
        elif y == "BUS":
            total += 12
        elif y == "PLANE":
            total += 18
        else:  # taxi
            total += 28
    routeAtt["negative"][i]=total;
    i += 1
#score counter
i=0;
distanceWeightage = 50
negativeWeightage = 25
positiveWeightage = 25

for x in routeAtt["score"]:
    score= (routeAtt["distance"][i] * distanceWeightage) + (routeAtt["negative"][i] * negativeWeightage) - (routeAtt["positive"][i] * positiveWeightage);
    routeAtt["score"][i]=int(score)
    i+=1;

print("positive : ",routeAtt["positive"])
print("negative : ",routeAtt["negative"])
print("score : " ,routeAtt["score"])
print()

for i in range (len(routeAtt["route"])):
    print("Route ", i + 1," : ", routeAtt["route"][i])
    print("Transport: ", routeAtt["mode"][i])
    print("Positive: ", routeAtt["positive"][i])
    print("Negative: ", routeAtt["negative"][i])
    print("Score: ", routeAtt["score"][i])
    print()

#sorting
routeTemp = routeAtt["route"]
scoreTemp = routeAtt["score"]


import numpy
routeTemp = numpy.array(routeTemp)
scoreTemp = numpy.array(scoreTemp)
inds = scoreTemp.argsort()
pathSorted = routeTemp[inds]

#printing
print()
print("Recommended routes (1=Most recommended, 5=Least recommended)")
i = 1
for x in pathSorted:
    print(i, end = ": ")
    i+=1
    print(x)
# Out:
# --------------------------------- PROBLEM 3 ---------------------------------
# positive :  [27, 93, 102, 86, 65]
# negative :  [32, 86, 90, 52, 50]
# score :  [15525, 16725, 17650, 18200, 16075]
#
# Route  1  :  ['KL SENTRAL  > KLIA > TERMINAL TUTA > LEGOLAND']
# Transport:  ['KLIA EXPRESS', 'BUS', 'BUS']
# Positive:  27
# Negative:  32
# Score:  15525
#
# Route  2  :  ['KL SENTRAL  > TERMINAL SKYPARK KOMUTER STATION > SZB AIRPORT > SENAI AIRPORT > JB SENTRAL  > LEGOLAND']
# Transport:  ['KTM', 'TAXI', 'PLANE', 'BUS', 'BUS']
# Positive:  93
# Negative:  86
# Score:  16725
#
# Route  3  :  ['KL SENTRAL  > TERMINAL SKYPARK KOMUTER STATION > SZB AIRPORT > SINGAPORE SELETAR > LEGOLAND']
# Transport:  ['KTM', 'TAXI', 'PLANE', 'TAXI']
# Positive:  102
# Negative:  90
# Score:  17650
#
# Route  4  :  ['KL SENTRAL  > KLIA > CHANGI AIRPORT > TANAH MERAH >JURONG EAST > LEGOLAND']
# Transport:  ['KLIA EXPRESS', 'PLANE', 'SMRT', 'SMRT', 'BUS']
# Positive:  86
# Negative:  52
# Score:  18200
#
# Route  5  :  ['KL SENTRAL  > KLIA > SENAI AIRPORT > JB SENTRAL > LEGOLAND']
# Transport:  ['KLIA EXPRESS', 'PLANE', 'BUS', 'BUS']
# Positive:  65
# Negative:  50
# Score:  16075
#
#
# Recommended routes (1=Most recommended, 5=Least recommended)
# 1: ['KL SENTRAL  > KLIA > TERMINAL TUTA > LEGOLAND']
# 2: ['KL SENTRAL  > KLIA > SENAI AIRPORT > JB SENTRAL > LEGOLAND']
# 3: ['KL SENTRAL  > TERMINAL SKYPARK KOMUTER STATION > SZB AIRPORT > SENAI AIRPORT > JB SENTRAL  > LEGOLAND']
# 4: ['KL SENTRAL  > TERMINAL SKYPARK KOMUTER STATION > SZB AIRPORT > SINGAPORE SELETAR > LEGOLAND']
# 5: ['KL SENTRAL  > KLIA > CHANGI AIRPORT > TANAH MERAH >JURONG EAST > LEGOLAND']
